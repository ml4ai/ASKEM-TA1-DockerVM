# %%
# Set some environment variables for demo purposes
# %env SKEMA_HOST=http://127.0.0.1:9005
# %env MIT_HOST=http://localhost:8000
# %env OPENAI_KEY=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
# Out:
# env: SKEMA_HOST=http://127.0.0.1:9005
# env: MIT_HOST=http://localhost:8000
# env: OPENAI_KEY=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

# %% [markdown]
# # Text Reading Integration Notebook

# %% [markdown]
# ## SKEMA Annotation Client

# %%
# Client code for SKEMA TR
from typing import Any, Dict, Union
import requests, os

def annotate_text_with_skema(text:Union[str, list[str]]) -> list[Dict[str, Any]]:
	endpoint = f"{os.environ['SKEMA_HOST']}/textFileToMentions"
	if isinstance(text, str):
		payload = [text] # If the text to annotate is a single string representing the contents of a document, make it a list with a single element
	else:
		payload = text # if the text to annotate is already a list of documents to annotate, it is the payload itself
	response = requests.post(endpoint, json=payload, timeout=120)
	if response.status_code == 200:
		return response.json()
	else:
		raise RuntimeError(f"Calling {endpoint} failed with HTTP code {response.status_code}")

# %% [markdown]
# ## MIT Annotation Client

# %%
# Client code for MIT TR

def annotate_text_with_mit(texts:Union[str, list[str]]) -> list[Dict[str, Any]]:
	endpoint = f"{os.environ['MIT_HOST']}/annotation/find_text_vars/"
	if isinstance(texts, str):
		texts = [texts] # If the text to annotate is a single string representing the contents of a document, make it a list with a single element
	
	# TODO paralelize this
	return_values = list()
	for ix, text in enumerate(texts):
		params = {
			"gpt_key": os.environ['OPENAI_KEY'],
			"text": text
		}
		response = requests.post(endpoint, params=params)
		if response.status_code == 200:
			return_values.append(response.json())
		else:
			raise RuntimeError(f"Calling {endpoint} on the {ix}th input failed with HTTP code {response.status_code}")
	return return_values

# %% [markdown]
# ## Normalization of Extractions

# %%
import json
from pathlib import Path
import tempfile
from typing import Optional, Dict, Any
from askem_extractions.importers import import_arizona, import_mit
from askem_extractions.importers.mit import merge_collections
from askem_extractions.data_model import AttributeCollection
import itertools as it

def normalize_extractions(
        arizona_extractions:Optional[Dict[str, Any]],
        mit_extractions:Optional[Dict]
    ) -> AttributeCollection:
    collections = list()
    with tempfile.TemporaryDirectory() as tmpdirname:
        
        skema_path = os.path.join(tmpdirname, "skema.json")
        mit_path = os.path.join(tmpdirname, "mit.json")

        if arizona_extractions:
            try:
                with open(skema_path, "w") as f:
                    json.dump(arizona_extractions, f)
                canonical_arizona = import_arizona(Path(skema_path))
                collections.append(canonical_arizona)
            except Exception as ex:
                print(ex)
        if mit_extractions:
            try:
                with open(mit_path, "w") as f:
                    json.dump(mit_extractions, f)
                canonical_mit = import_mit(Path(mit_path))
                collections.append(canonical_mit)
            except Exception as ex:
                print(ex)

        if arizona_extractions and mit_extractions:
            # Merge both with some de de-duplications
            params = {
                "gpt_key": os.environ['OPENAI_KEY']
            }

            data = {
                "mit_file": open(mit_path).read(),
                "arizona_file": open(skema_path).read()
            }
            response = requests.post(f"{os.environ['MIT_HOST']}/integration/get_mapping", params=params, data=data)

            if response.status_code == 200:
                map_data = response.text()
                map_path = os.path.join(tmpdirname, "mapping.txt")
                with open(map_path, 'w')as f:
                    f.write(map_data)
                merged_collection = \
                    merge_collections(
                        a_collection=collections[0],
                        m_collection=collections[1],
                        map_path=Path(map_path)
                    )
                
                # Return the merged collection here
                return merged_collection
            

    # Merge the colletions into a attribute collection
    attributes = list(it.chain.from_iterable(c.attributes for c in collections))

    return AttributeCollection(attributes=attributes)

# %% [markdown]
# ## Integrated Workflow

# %%
def integrated_text_extractions(texts:Union[str, list[str]]) -> AttributeCollection:
    skema_extractions = annotate_text_with_skema(texts)
    mit_extractions = annotate_text_with_mit(texts)

    results = list()
    for skema, mit in zip(skema_extractions, mit_extractions):
        normalized = normalize_extractions(arizona_extractions=skema, mit_extractions=mit)
        results.append(normalized)
    return results

# %% [markdown]
# ## Example

# %%
# Read a paper from the example directory
test_text = open("../inputs/1-s2.0-S2211379721005490-main.txt").read()

# Run the integrated pipeline
extractions = integrated_text_extractions(test_text)

# Print the result
for attribute in extractions[0].attributes:
    print(attribute)
# Out:
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-1690295439'), names=[Name(id=ID(id='T:447086538'), name='E', extraction_source=TextExtraction(page=0, block=0, char_start=17814, char_end=17815, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 617833)))], descriptions=[Description(id=ID(id='T:-1178270728'), source='Matouk AE', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=17817, char_end=17826, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 617833)))], value_specs=[], groundings=[Grounding(grounding_text='LolC/E', grounding_id='vo:0010921', source=[], score=1.0000001192092896, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 617943)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-89715416'), names=[Name(id=ID(id='T:-210121123'), name='AE', extraction_source=TextExtraction(page=0, block=0, char_start=17824, char_end=17826, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 619850)))], descriptions=[Description(id=ID(id='T:1775224888'), source='Ahmed E', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=17808, char_end=17815, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 619850)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:1660582516'), names=[Name(id=ID(id='T:-235664307'), name='WHO', extraction_source=TextExtraction(page=0, block=0, char_start=3778, char_end=3781, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620054)))], descriptions=[Description(id=ID(id='T:189117706'), source='World Health Organization', grounding=[Grounding(grounding_text='World Health Organization', grounding_id='ncit:C75419', source=[], score=0.9602659344673157, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620124)))], extraction_source=TextExtraction(page=0, block=0, char_start=3751, char_end=3776, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620054)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:1980527304'), names=[Name(id=ID(id='T:106221015'), name='nRNA', extraction_source=TextExtraction(page=0, block=0, char_start=3225, char_end=3229, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620224)))], descriptions=[Description(id=ID(id='T:-312714687'), source='positive single strand\\', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=3202, char_end=3225, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620224)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:5167108'), names=[Name(id=ID(id='T:-1557044590'), name='R2 ηyi', extraction_source=TextExtraction(page=0, block=0, char_start=6889, char_end=6895, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620386)))], descriptions=[], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:1441320649'), names=[Name(id=ID(id='T:1855061923'), name='i', extraction_source=TextExtraction(page=0, block=0, char_start=6930, char_end=6931, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620485)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:861805746'), value=Value(source='1, 2', grounding=[Grounding(grounding_text='SG33-VP2/5', grounding_id='vo:0004706', source=[], score=0.7700864672660828, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620555)))], extraction_source=TextExtraction(page=0, block=0, char_start=6934, char_end=6938, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620485)))], groundings=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.994598925113678, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620512)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-313969182'), names=[Name(id=ID(id='T:-2068312296'), name='i', extraction_source=TextExtraction(page=0, block=0, char_start=6940, char_end=6941, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620637)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:-1409922483'), value=Value(source='1', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=6942, char_end=6943, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620637)))], groundings=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.994598925113678, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620664)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-1521158539'), names=[Name(id=ID(id='T:-973621380'), name='c', extraction_source=TextExtraction(page=0, block=0, char_start=12106, char_end=12107, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620756)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:-1082490017'), value=Value(source='0.0001', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=12110, char_end=12116, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620756)))], groundings=[Grounding(grounding_text='BoNT/C', grounding_id='vo:0004004', source=[], score=0.7589514851570129, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620784)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-265205421'), names=[Name(id=ID(id='T:-1052224669'), name='d', extraction_source=TextExtraction(page=0, block=0, char_start=12118, char_end=12119, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620906)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:-206258953'), value=Value(source='0.02', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=12122, char_end=12126, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 620906)))], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:1448095724'), names=[Name(id=ID(id='T:-317718225'), name='a', extraction_source=TextExtraction(page=0, block=0, char_start=12085, char_end=12086, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621055)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:1722388882'), value=Value(source='0.012', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=12089, char_end=12094, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621055)))], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:1695677557'), names=[Name(id=ID(id='T:-523175563'), name='e', extraction_source=TextExtraction(page=0, block=0, char_start=12128, char_end=12129, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621202)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:-1724085662'), value=Value(source='0.98', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=12132, char_end=12136, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621202)))], groundings=[Grounding(grounding_text='LolC/E', grounding_id='vo:0010921', source=[], score=1.0000001192092896, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621229)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:1871432167'), names=[Name(id=ID(id='T:-1398348914'), name='b', extraction_source=TextExtraction(page=0, block=0, char_start=12096, char_end=12097, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621349)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:-262537340'), value=Value(source='0.01', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=12100, char_end=12104, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621349)))], groundings=[Grounding(grounding_text='AIDSVAX B/B', grounding_id='vo:0000405', source=[], score=0.8989673256874084, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621376)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:604043764'), names=[Name(id=ID(id='T:-1188661376'), name='LV', extraction_source=TextExtraction(page=0, block=0, char_start=7854, char_end=7856, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621498)))], descriptions=[Description(id=ID(id='T:-1425209000'), source='classic  Lotka-Volterra', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=7828, char_end=7851, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621498)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:-941675546'), names=[Name(id=ID(id='T:-880477328'), name='Jacobian of model', extraction_source=TextExtraction(page=0, block=0, char_start=7679, char_end=7696, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621633)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:-2128312276'), value=Value(source='4', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=7672, char_end=7673, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621633)))], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-1794794890'), names=[Name(id=ID(id='T:-1560019756'), name='LAS', extraction_source=TextExtraction(page=0, block=0, char_start=10785, char_end=10788, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621750)))], descriptions=[Description(id=ID(id='T:-555807467'), source='coexistence equilibrium point of system', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=10738, char_end=10777, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621750)))], value_specs=[], groundings=[Grounding(grounding_text='Las Vegas', grounding_id='ncit:C44541', source=[], score=0.7691847085952759, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621777)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-1919214947'), names=[Name(id=ID(id='T:1098022108'), name='B', extraction_source=TextExtraction(page=0, block=0, char_start=16151, char_end=16152, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621941)))], descriptions=[Description(id=ID(id='T:-2104599840'), source='Vela-Perez M', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=16168, char_end=16180, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621941)))], value_specs=[], groundings=[Grounding(grounding_text='AIDSVAX B/B', grounding_id='vo:0000405', source=[], score=0.8989673256874084, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 621972)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:-1941371706'), names=[Name(id=ID(id='T:1098022108'), name='B', extraction_source=TextExtraction(page=0, block=0, char_start=16151, char_end=16152, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622142)))], descriptions=[Description(id=ID(id='T:-516742654'), source='] Ivorra', grounding=[Grounding(grounding_text='Abdala', grounding_id='vo:0005082', source=[], score=0.7932197451591492, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622212)))], extraction_source=TextExtraction(page=0, block=0, char_start=16142, char_end=16150, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622142)))], value_specs=[], groundings=[Grounding(grounding_text='AIDSVAX B/B', grounding_id='vo:0000405', source=[], score=0.8989673256874084, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622169)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:721753818'), names=[Name(id=ID(id='T:1098022108'), name='B', extraction_source=TextExtraction(page=0, block=0, char_start=16151, char_end=16152, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622336)))], descriptions=[Description(id=ID(id='T:-516742654'), source='] Ivorra', grounding=[Grounding(grounding_text='Abdala', grounding_id='vo:0005082', source=[], score=0.7932197451591492, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622416)))], extraction_source=TextExtraction(page=0, block=0, char_start=16142, char_end=16150, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622336)))], value_specs=[], groundings=[Grounding(grounding_text='AIDSVAX B/B', grounding_id='vo:0000405', source=[], score=0.8989673256874084, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622373)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-1349597540'), names=[Name(id=ID(id='T:-1296324114'), name='d', extraction_source=TextExtraction(page=0, block=0, char_start=8552, char_end=8553, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622542)))], descriptions=[], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-1225232436'), names=[Name(id=ID(id='T:-1296324114'), name='d', extraction_source=TextExtraction(page=0, block=0, char_start=8552, char_end=8553, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622643)))], descriptions=[Description(id=ID(id='T:1734042212'), source='death rate', grounding=[Grounding(grounding_text='cumulative death rates', grounding_id='cemo:cumulative_death_rates', source=[], score=0.9054759740829468, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622713)))], extraction_source=TextExtraction(page=0, block=0, char_start=8529, char_end=8539, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622643)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:277501126'), names=[Name(id=ID(id='T:-1296324114'), name='d', extraction_source=TextExtraction(page=0, block=0, char_start=8552, char_end=8553, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622780)))], descriptions=[Description(id=ID(id='T:1734042212'), source='death rate', grounding=[Grounding(grounding_text='cumulative death rates', grounding_id='cemo:cumulative_death_rates', source=[], score=0.9054759740829468, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622851)))], extraction_source=TextExtraction(page=0, block=0, char_start=8529, char_end=8539, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622780)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:953906431'), names=[Name(id=ID(id='T:1233977736'), name='y2(t)', extraction_source=TextExtraction(page=0, block=0, char_start=8304, char_end=8309, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622932)))], descriptions=[Description(id=ID(id='T:-943670014'), source='infected individual population', grounding=[Grounding(grounding_text='infected population', grounding_id='apollosv:00000233', source=[], score=0.9308826923370361, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623002)))], extraction_source=TextExtraction(page=0, block=0, char_start=8261, char_end=8291, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 622932)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:1639110070'), names=[Name(id=ID(id='T:1233977736'), name='y2(t)', extraction_source=TextExtraction(page=0, block=0, char_start=8304, char_end=8309, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623069)))], descriptions=[Description(id=ID(id='T:-943670014'), source='infected individual population', grounding=[Grounding(grounding_text='infected population', grounding_id='apollosv:00000233', source=[], score=0.9308826923370361, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623138)))], extraction_source=TextExtraction(page=0, block=0, char_start=8261, char_end=8291, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623069)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:1259409030'), names=[Name(id=ID(id='T:1233977736'), name='y2(t)', extraction_source=TextExtraction(page=0, block=0, char_start=8304, char_end=8309, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623204)))], descriptions=[Description(id=ID(id='T:-943670014'), source='infected individual population', grounding=[Grounding(grounding_text='infected population', grounding_id='apollosv:00000233', source=[], score=0.9308826923370361, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623274)))], extraction_source=TextExtraction(page=0, block=0, char_start=8261, char_end=8291, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623204)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:1416161858'), names=[Name(id=ID(id='T:2020043776'), name='b', extraction_source=TextExtraction(page=0, block=0, char_start=8325, char_end=8326, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623339)))], descriptions=[Description(id=ID(id='T:-1636916396'), source='infected individual population is given by y2(t) at time t. Let', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=8261, char_end=8324, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623339)))], value_specs=[], groundings=[Grounding(grounding_text='AIDSVAX B/B', grounding_id='vo:0000405', source=[], score=0.8989673256874084, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623366)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:308445401'), names=[Name(id=ID(id='T:25594654'), name='infected individual population is given by y2(t) at time t. Let b', extraction_source=TextExtraction(page=0, block=0, char_start=8261, char_end=8326, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623475)))], descriptions=[], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:-821538198'), names=[Name(id=ID(id='T:1454866333'), name='E2', extraction_source=TextExtraction(page=0, block=0, char_start=11649, char_end=11651, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623574)))], descriptions=[Description(id=ID(id='T:-2051783844'), source='coexistence  point', grounding=[Grounding(grounding_text='Pitkas Point', grounding_id='ncit:C44618', source=[], score=0.7740926742553711, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623642)))], extraction_source=TextExtraction(page=0, block=0, char_start=11629, char_end=11647, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623574)))], value_specs=[], groundings=[Grounding(grounding_text='E2', grounding_id='vo:0011305', source=[], score=0.9999999403953552, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623600)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-1386046336'), names=[Name(id=ID(id='T:444624797'), name='y1', extraction_source=TextExtraction(page=0, block=0, char_start=12995, char_end=12997, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623709)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:-23269525'), value=Value(source='99.99, 60.3', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=13005, char_end=13016, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623709)))], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:2063133550'), names=[Name(id=ID(id='T:1548643784'), name='y1', extraction_source=TextExtraction(page=0, block=0, char_start=12968, char_end=12970, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623849)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:611965638'), value=Value(source='0.01, 0.01', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=12978, char_end=12988, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623849)))], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:221830702'), names=[Name(id=ID(id='T:-372646224'), name='n', extraction_source=TextExtraction(page=0, block=0, char_start=4659, char_end=4660, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623999)))], descriptions=[Description(id=ID(id='T:-1987229612'), source='surrounding\\', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=4647, char_end=4659, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 623999)))], value_specs=[], groundings=[Grounding(grounding_text='V-LSG/N', grounding_id='vo:0004083', source=[], score=1.0000001192092896, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624031)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-1640066295'), names=[Name(id=ID(id='T:-2050460340'), name='AA', extraction_source=TextExtraction(page=0, block=0, char_start=17127, char_end=17129, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624214)))], descriptions=[Description(id=ID(id='T:1215819392'), source='Matouk AE', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=17107, char_end=17116, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624214)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:1801288345'), names=[Name(id=ID(id='T:-294628066'), name='S', extraction_source=TextExtraction(page=0, block=0, char_start=19038, char_end=19039, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624448)))], descriptions=[Description(id=ID(id='T:-1515165824'), source='Matouk AE, Chaudhary H, Kant S. Control and synchronization of fractional-order chaotic satellite systems using feedback and adaptive control techniques', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=19041, char_end=19193, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624448)))], value_specs=[], groundings=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.7847759127616882, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624477)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:266502470'), names=[Name(id=ID(id='T:-294628066'), name='S', extraction_source=TextExtraction(page=0, block=0, char_start=19038, char_end=19039, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624715)))], descriptions=[Description(id=ID(id='T:-156911386'), source='synchronization of fractional-order chaotic satellite systems', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=19085, char_end=19146, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624715)))], value_specs=[], groundings=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.7847759127616882, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624743)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-994068700'), names=[Name(id=ID(id='T:-294628066'), name='S', extraction_source=TextExtraction(page=0, block=0, char_start=19038, char_end=19039, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624972)))], descriptions=[Description(id=ID(id='T:-1649638244'), source='Kant S. Control', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=19065, char_end=19080, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 624972)))], value_specs=[], groundings=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.7847759127616882, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625000)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:1297564869'), names=[Name(id=ID(id='T:-294628066'), name='S', extraction_source=TextExtraction(page=0, block=0, char_start=19038, char_end=19039, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625223)))], descriptions=[Description(id=ID(id='T:-1649638244'), source='Kant S. Control', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=19065, char_end=19080, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625223)))], value_specs=[], groundings=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.7847759127616882, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625250)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:736448387'), names=[Name(id=ID(id='T:844352278'), name='AE', extraction_source=TextExtraction(page=0, block=0, char_start=19048, char_end=19050, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625470)))], descriptions=[Description(id=ID(id='T:1537513313'), source='Kumar S', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=19032, char_end=19039, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625470)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:-336719001'), names=[Name(id=ID(id='T:472369803'), name='nHence', extraction_source=TextExtraction(page=0, block=0, char_start=9314, char_end=9320, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625714)))], descriptions=[Description(id=ID(id='T:-1434885861'), source='fractional\\', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=9303, char_end=9314, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625714)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:648684206'), names=[Name(id=ID(id='T:-200751020'), name='αy1', extraction_source=TextExtraction(page=0, block=0, char_start=9419, char_end=9422, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625833)))], descriptions=[Description(id=ID(id='T:1530889397'), source='model', grounding=[Grounding(grounding_text='Susceptible-Infected-Resistant model', grounding_id='apollosv:00000549', source=[], score=0.9977449774742126, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625903)))], extraction_source=TextExtraction(page=0, block=0, char_start=9400, char_end=9405, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625833)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-2116691301'), names=[Name(id=ID(id='T:-1519129548'), name='c', extraction_source=TextExtraction(page=0, block=0, char_start=12683, char_end=12684, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625973)))], descriptions=[Description(id=ID(id='T:1853742544'), source='dividuals', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=12656, char_end=12665, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 625973)))], value_specs=[], groundings=[Grounding(grounding_text='BoNT/C', grounding_id='vo:0004004', source=[], score=0.7589514851570129, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626001)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:-774593155'), names=[Name(id=ID(id='T:-1154035626'), name='immigration  rate  of  infected', extraction_source=TextExtraction(page=0, block=0, char_start=12619, char_end=12650, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626182)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:1917782752'), value=Value(source='0.012', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=12602, char_end=12607, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626182)))], groundings=[Grounding(grounding_text='rate of infectious contacts', grounding_id='cemo:rate_of_infectious_contacts', source=[], score=0.8282712697982788, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626212)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-2092322421'), names=[Name(id=ID(id='T:1430831620'), name='approximately c', extraction_source=TextExtraction(page=0, block=0, char_start=12669, char_end=12684, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626338)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:-720911975'), value=Value(source='0.0001', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=12687, char_end=12693, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626338)))], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:1461123658'), names=[Name(id=ID(id='T:1177142454'), name='A', extraction_source=TextExtraction(page=0, block=0, char_start=18516, char_end=18517, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626498)))], descriptions=[Description(id=ID(id='T:-1076395458'), source='dynamics and chaos control for the fractional-order geomagnetic field model', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=18546, char_end=18621, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626498)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:1496693927'), names=[Name(id=ID(id='T:1177142454'), name='A', extraction_source=TextExtraction(page=0, block=0, char_start=18516, char_end=18517, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626691)))], descriptions=[Description(id=ID(id='T:-702521144'), source='chaos control', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=18559, char_end=18572, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626691)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:-326530761'), names=[Name(id=ID(id='T:1177142454'), name='A', extraction_source=TextExtraction(page=0, block=0, char_start=18516, char_end=18517, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626886)))], descriptions=[Description(id=ID(id='T:-138716964'), source='] Al-khedhairi', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=18501, char_end=18515, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 626886)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:-1395280998'), names=[Name(id=ID(id='T:1177142454'), name='A', extraction_source=TextExtraction(page=0, block=0, char_start=18516, char_end=18517, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627070)))], descriptions=[Description(id=ID(id='T:-138716964'), source='] Al-khedhairi', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=18501, char_end=18515, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627070)))], value_specs=[], groundings=[], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:740208089'), names=[Name(id=ID(id='T:2086041515'), name='Eα', extraction_source=TextExtraction(page=0, block=0, char_start=7352, char_end=7354, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627243)))], descriptions=[], value_specs=[ValueSpec(id=ID(id='T:333194818'), value=Value(source='0', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=7370, char_end=7371, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627243)))], groundings=[Grounding(grounding_text='LolC/E', grounding_id='vo:0010921', source=[], score=0.7579770088195801, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627269)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='R:-1126828285'), names=[Name(id=ID(id='T:2086041515'), name='Eα', extraction_source=TextExtraction(page=0, block=0, char_start=7352, char_end=7354, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627395)))], descriptions=[Description(id=ID(id='T:-1780770122'), source='lim E', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=7348, char_end=7353, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627395)))], value_specs=[], groundings=[Grounding(grounding_text='LolC/E', grounding_id='vo:0010921', source=[], score=0.7579770088195801, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627422)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:325879043'), names=[Name(id=ID(id='T:2086041515'), name='Eα', extraction_source=TextExtraction(page=0, block=0, char_start=7352, char_end=7354, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627568)))], descriptions=[Description(id=ID(id='T:-1780770122'), source='lim E', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=7348, char_end=7353, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627568)))], value_specs=[ValueSpec(id=ID(id='T:333194818'), value=Value(source='0', grounding=[], extraction_source=TextExtraction(page=0, block=0, char_start=7370, char_end=7371, document_reference=ID(id='N/A'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627568)))], groundings=[Grounding(grounding_text='LolC/E', grounding_id='vo:0010921', source=[], score=0.7579770088195801, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627595)))], data_columns=None)
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='E:420075613'), names=[Name(id=ID(id='T:-513987212'), name='HB', extraction_source=TextExtraction(page=0, block=0, char_start=15737, char_end=15739, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627774)))], descriptions=[Description(id=ID(id='T:-537182227'), source='Novel Corona virus disease infection in Tunisia', grounding=[Grounding(grounding_text='Influenza A virus vaccine, A-California-7-2009 (H1N1)-like virus', grounding_id='vo:0003497', source=[], score=0.764420747756958, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627847)))], extraction_source=TextExtraction(page=0, block=0, char_start=15750, char_end=15797, document_reference=ID(id='N/A')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 627774)))], value_specs=[], groundings=[], data_columns=None)
# ...
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v34'), names=[Name(id=ID(id='v34'), name='e', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v34'), source=' cure rateDα', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432))), Description(id=ID(id='v34'), source=' Coefficient of y2', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v35'), names=[Name(id=ID(id='v35'), name='b', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v35'), source=' Coefficient of y2', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432))), Description(id=ID(id='v35'), source=' immigration rate of infected individuals', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v36'), names=[Name(id=ID(id='v36'), name='λi', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v36'), source=' Eigenvalues of matrix J', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v37'), names=[Name(id=ID(id='v37'), name='J', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v37'), source=' Matrix of linearized modela', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v38'), names=[Name(id=ID(id='v38'), name='NoneModel (4)', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v38'), source=' fractional case of Lotka-Volterra model of COVID-19.', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v39'), names=[Name(id=ID(id='v39'), name='Integer-order counterpart (see Fig. 2)', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v39'), source=' integer-order case of Lotka-Volterra model of COVID-19.', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v40'), names=[Name(id=ID(id='v40'), name='Memory effect', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v40'), source=' eliminates oscillations in integer-order case after some times.', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v41'), names=[Name(id=ID(id='v41'), name='Fractional parameters', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v41'), source=' controllers to flattening the curves of infected individuals.', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v42'), names=[Name(id=ID(id='v42'), name='NoneFractional parameter', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v42'), source=' mitigating the spread of the pandemic', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v43'), names=[Name(id=ID(id='v43'), name='Integer-order cases', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v43'), source=' influence of the fractional parameter', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v44'), names=[Name(id=ID(id='v44'), name='Software', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v44'), source=' Data curation, Software', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[Grounding(grounding_text='software', grounding_id='iao:0000010', source=[], score=1.0, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432))), Grounding(grounding_text='software method', grounding_id='iao:0000591', source=[], score=1.0, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v45'), names=[Name(id=ID(id='v45'), name='Formal analysis', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v45'), source=' Formal analysis', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v46'), names=[Name(id=ID(id='v46'), name='Validation', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v46'), source=' ValidationSusceptible-infected models', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v47'), names=[Name(id=ID(id='v47'), name='Multi-drug resistance', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v47'), source=' Models for COVID-19 with multi-drug resistance', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[Grounding(grounding_text='ATP-dependent translocase ABCB1', grounding_id='pr:000001891', source=[], score=1.0, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432))), Grounding(grounding_text='multidrug resistance-associated protein 1', grounding_id='pr:000003554', source=[], score=1.0, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v48'), names=[Name(id=ID(id='v48'), name='Quarantine strategy', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v48'), source=' The impact of the quarantine strategyNoneGLV model', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v49'), names=[Name(id=ID(id='v49'), name='Hastings-Powell food chain model', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v49'), source=' fractional-order model', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v50'), names=[Name(id=ID(id='v50'), name='Lotka-Volterra predator–prey model', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v50'), source=' fractional-order model', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v51'), names=[Name(id=ID(id='v51'), name='Lorenz family', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v51'), source=' two different fractional systems', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.anchored_extraction: 'anchored_extraction'> amr_element_id=None payload=AnchoredExtraction(id=ID(id='v52'), names=[Name(id=ID(id='v52'), name='complex networks', extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], descriptions=[Description(id=ID(id='v52'), source=' antimicrobial resistance modelsNoneNoneNoneNone', grounding=None, extraction_source=None, provenance=Provenance(method='MIT extractor V1.0 - text, dataset, formula annotation (chunwei@mit.edu)', timestamp=datetime.datetime(2023, 6, 26, 23, 48, 37, 658432)))], value_specs=None, groundings=[], data_columns=[])
# type=<AttributeType.document_collection: 'document_collection'> amr_element_id=None payload=DocumentCollection(documents=[DocumentReference(id=ID(id='1'), source_file='N/A', doi='')])

# %% [markdown]
# # TODOS

# %% [markdown]
# - Parameterize the endpoint URLs
# - Fetch the OPEN_AI key from the environment
# - Make the annotations asynchronous and add flags to control which to run
# - Make equivalent functions that read COSMOS json/binaries instead of text
