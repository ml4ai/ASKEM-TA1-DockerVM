# %% [markdown]
# # Text Reading Integration Notebook

# %% [markdown]
# ### Running a PDF through COSMOS

# %%
import requests

# Endpint configuration. Set the host correctly depending on where are you running this code snippet
# ENDPOINT="https://api.askem.lum.ai" # Uncomment this line to use SKEMA's web service
ENDPOINT = "http://127.0.0.1:8000" # Uncomment this line to use the docker compose service

response = requests.post(
    f"{ENDPOINT}/text-reading/cosmos_to_json",
            files=[
                ("pdf", ("ijerp.pdf", open("../../data/pdf/ijerph-18-09027.pdf", 'rb')))
            ]
    )

if response.status_code == 200:
    print(response.json())
else:
    print(f"Error {response.status_code} - {response.text}")
# Out:
# [{'pdf_name': 'ijerp.pdf', 'dataset_id': 'ijerp', 'page_num': 1, 'img_pth': '/tmp/tmpaegyk2uw/ijerp.pdf_1_pad', 'pdf_dims': [0.0, 0.0, 595.276, 841.89], 'bounding_box': [82.0, 107.0, 1275.0, 195.0], 'classes': ['Equation label', 'Section Header', 'Page Header', 'Body Text', 'Figure', 'Other', 'Equation', 'Reference text', 'Figure Caption', 'Table', 'Page Footer', 'Table Note', 'Table Caption', 'Abstract'], 'scores': [-5.1587600708, -8.3740234375, -10.0186519623, -10.2147502899, -11.1155567169, -11.1168165207, -11.2150306702, -13.100736618, -15.0583581924, -15.1461448669, -15.9341535568, -18.4104003906, -18.7148742676, -18.9958457947], 'content': '', 'postprocess_cls': 'Page Header', 'postprocess_score': 0.9985129237, 'detect_cls': 'Equation label', 'detect_score': -5.1587600708}, {'pdf_name': 'ijerp.pdf', 'dataset_id': 'ijerp', 'page_num': 1, 'img_pth': '/tmp/tmpaegyk2uw/ijerp.pdf_1_pad', 'pdf_dims': [0.0, 0.0, 595.276, 841.89], 'bounding_box': [1176.5424804688, 121.4962387085, 1278.4833984375, 182.4691772461], 'classes': ['Equation', 'Body Text', 'Equation label', 'Figure', 'Reference text', 'Figure Caption', 'Other', 'Section Header', 'Page Header', 'Table', 'Page Footer', 'Abstract', 'Table Note', 'Table Caption'], 'scores': [-5.5467596054, -5.9291982651, -8.2758188248, -9.0827665329, -10.600771904, -10.9795484543, -12.0400781631, -12.0700139999, -13.8072986603, -13.967051506, -14.0430736542, -15.630074501, -15.9073972702, -17.6657371521], 'content': '', 'postprocess_cls': 'Equation', 'postprocess_score': 0.6392424703, 'detect_cls': 'Equation', 'detect_score': -5.5467596054}, {'pdf_name': 'ijerp.pdf', 'dataset_id': 'ijerp', 'page_num': 1, 'img_pth': '/tmp/tmpaegyk2uw/ijerp.pdf_1_pad', 'pdf_dims': [0.0, 0.0, 595.276, 841.89], 'bounding_box': [80.0, 234.0, 1197.0, 305.0], 'classes': ['Body Text', 'Other', 'Equation label', 'Section Header', 'Reference text', 'Table Note', 'Page Footer', 'Figure', 'Abstract', 'Equation', 'Page Header', 'Table', 'Figure Caption', 'Table Caption'], 'scores': [-1.9901316166, -7.2413005829, -11.0127258301, -12.7747974396, -13.0994443893, -14.0690536499, -14.291308403, -14.6298599243, -14.6906614304, -15.8366947174, -16.1897945404, -17.3274078369, -17.9256343842, -20.9608535767], 'content': 'Article Dynamical Analysis of Universal Masking on the Pandemic', 'postprocess_cls': 'Body Text', 'postprocess_score': 0.9915181994, 'detect_cls': 'Body Text', 'detect_score': -1.9901316166}, {'pdf_name': 'ijerp.pdf', 'dataset_id': 'ijerp', 'page_num': 1, 'img_pth': '/tmp/tmpaegyk2uw/ijerp.pdf_1_pad', 'pdf_dims': [0.0, 0.0, 595.276, 841.89], 'bounding_box': [83.0, 343.0, 1044.0, 370.0], 'classes': ['Section Header', 'Other', 'Equation label', 'Equation', 'Body Text', 'Page Footer', 'Figure', 'Reference text', 'Abstract', 'Table Note', 'Table Caption', 'Table', 'Figure Caption', 'Page Header'], 'scores': [-2.0359969139, -2.7293670177, -4.5173983574, -5.2254776955, -6.2279496193, -6.3648195267, -6.7869443893, -7.0129766464, -7.4127578735, -7.4599442482, -7.9811425209, -8.0227499008, -8.2341270447, -8.6221017838], 'content': 'Brandon Kaiheng Tay † , Carvalho Andrea Roby †, Jodi Wenjiang Wu † and Da Yang Tan *', 'postprocess_cls': 'Section Header', 'postprocess_score': 0.9153046608, 'detect_cls': 'Section Header', 'detect_score': -2.0359969139}, {'pdf_name': 'ijerp.pdf', 'dataset_id': 'ijerp', 'page_num': 1, 'img_pth': '/tmp/tmpaegyk2uw/ijerp.pdf_1_pad', 'pdf_dims': [0.0, 0.0, 595.276, 841.89], 'bounding_box': [380.0, 418.0, 1226.0, 535.0], 'classes': ['Page Footer', 'Other', 'Table Note', 'Table', 'Page Header', 'Figure', 'Body Text', 'Table Caption', 'Figure Caption', 'Reference text', 'Abstract', 'Section Header', 'Equation label', 'Equation'], 'scores': [-2.5402958393, -3.7719321251, -5.0042982101, -5.7879199982, -6.5720453262, -6.8396196365, -6.8587145805, -7.6577916145, -7.8302545547, -7.9546160698, -8.0541982651, -9.3438863754, -9.8779993057, -10.1744766235], 'content': 'Science, Mathematics and Technology,  ...

# %% [markdown]
# ### Plain Text Annotation Example

# %%
import requests

# Endpint configuration. Set the host correctly depending on where are you running this code snippet
# ENDPOINT="https://api.askem.lum.ai"
ENDPOINT = "http://127.0.0.1:8000" # Uncomment this line to use the docker compose service

# Read an example document to annotate
params = {
       "annotate_skema":True,
       "annotate_mit": False
    }

payload = {
  "texts": [
    "x = 0",
    "y = 1",
    "I: Infected population"
  ],
    "amrs": []
}

response = requests.post(f"{ENDPOINT}/text-reading/integrated-text-extractions", params=params, json=payload)
if response.status_code == 200:
    print(response.json())
else:
    print(f"Error {response.status_code} - {response.text}")
# Out:
# {'outputs': [{'data': {'attributes': [{'type': 'anchored_entity', 'amr_element_id': None, 'payload': {'id': {'id': 'E:-589301722'}, 'mentions': [{'id': {'id': 'T:-1411656337'}, 'name': 'x', 'extraction_source': {'page': 0, 'block': 0, 'surrounding_passage': "`` x = 0 ''", 'char_start': 1, 'char_end': 2, 'document_reference': {'id': 'N/A'}}, 'provenance': {'method': 'Skema TR Pipeline rules', 'timestamp': '2024-03-20T23:57:29.664501'}}], 'text_descriptions': [], 'value_descriptions': [{'id': {'id': 'T:432832120'}, 'value': {'amount': '0', 'grounding': [], 'extraction_source': {'page': 0, 'block': 0, 'surrounding_passage': None, 'char_start': 5, 'char_end': 6, 'document_reference': {'id': 'N/A'}}}, 'units': None, 'type': None, 'bounds': None, 'provenance': {'method': 'Skema TR Pipeline rules', 'timestamp': '2024-03-20T23:57:29.664501'}}], 'groundings': [], 'data_columns': None}}, {'type': 'document_collection', 'amr_element_id': None, 'payload': {'documents': [{'id': {'id': 'N/A'}, 'source_file': 'N/A', 'doi': ''}]}}]}, 'errors': None}, {'data': {'attributes': [{'type': 'anchored_entity', 'amr_element_id': None, 'payload': {'id': {'id': 'E:-1176584284'}, 'mentions': [{'id': {'id': 'T:-2069258301'}, 'name': 'y', 'extraction_source': {'page': 0, 'block': 0, 'surrounding_passage': "`` y = 1 ''", 'char_start': 1, 'char_end': 2, 'document_reference': {'id': 'N/A'}}, 'provenance': {'method': 'Skema TR Pipeline rules', 'timestamp': '2024-03-20T23:57:29.671989'}}], 'text_descriptions': [], 'value_descriptions': [{'id': {'id': 'T:914019896'}, 'value': {'amount': '1', 'grounding': [], 'extraction_source': {'page': 0, 'block': 0, 'surrounding_passage': None, 'char_start': 5, 'char_end': 6, 'document_reference': {'id': 'N/A'}}}, 'units': None, 'type': None, 'bounds': None, 'provenance': {'method': 'Skema TR Pipeline rules', 'timestamp': '2024-03-20T23:57:29.671989'}}], 'groundings': [{'grounding_text': 'Meruvax I', 'grounding_id': 'vo:0003109', 'source': [], 'score': 0.7706882357597351, 'provenance': {'method': 'SKEMA-TR-Embedding', 'timestamp': '2024-03-20T23:57:29.672002'}}], 'data_columns': None}}, {'type': 'document_collection', 'amr_element_id': None, 'payload': {'documents': [{'id': {'id': 'N/A'}, 'source_file': 'N/A', 'doi': ''}]}}]}, 'errors': None}, {'data': {'attributes': [{'type': 'document_collection', 'amr_element_id': None, 'payload': {'documents': []}}]}, 'errors': None}], 'generalized_errors': None, 'aligned_amrs': []}

# %% [markdown]
# ### PDF Annotation Example

# %%
import requests

# Endpint configuration. Set the host correctly depending on where are you running this code snippet
ENDPOINT="https://api.askem.lum.ai"

params = {
	"annotate_skema":True,
	"annotate_mit": False
}

files = [("pdfs", ("ijerp.pdf", open("../../data/pdf/ijerph-18-09027.pdf", "rb")))]

response = requests.post(f"{ENDPOINT}/text-reading/integrated-pdf-extractions", params=params, files=files)
if response.status_code == 200:
	print(response.json())
else:
	print(f"Error {response.status_code} - {response.text}")
# Out:
# {'outputs': [{'data': {'attributes': [{'type': 'anchored_entity', 'amr_element_id': None, 'payload': {'id': {'id': 'E:-1621000196'}, 'mentions': [{'id': {'id': 'T:-2105346093'}, 'name': 'potential prevention of up', 'extraction_source': {'page': 1, 'block': 9, 'surrounding_passage': "It has shown success in limiting community spread of SARS 2003 [ 1 ] , and more recently , in Taiwan 's management of COVID-19 [ 2 ] .\nRecent hypothetical studies on masking by the states of New York and Washington suggests a potential prevention of up to 45 % of their projected death rates [ 3 ] .\nIn this study of potential face-mask usage for the general public , the authors investigated how public masking can control the infection , in the context of the USA .", 'char_start': 524, 'char_end': 550, 'document_reference': {'id': 'ijerp.pdf'}}, 'provenance': {'method': 'Skema TR Pipeline rules', 'timestamp': '2024-03-20T23:58:20.733738'}}], 'text_descriptions': [], 'value_descriptions': [{'id': {'id': 'T:-202544802'}, 'value': {'amount': '%', 'grounding': [], 'extraction_source': {'page': 1, 'block': 9, 'surrounding_passage': None, 'char_start': 556, 'char_end': 557, 'document_reference': {'id': 'ijerp.pdf'}}}, 'units': None, 'type': None, 'bounds': None, 'provenance': {'method': 'Skema TR Pipeline rules', 'timestamp': '2024-03-20T23:58:20.733738'}}], 'groundings': [{'grounding_text': 'Centers for Disease Control and Prevention', 'grounding_id': 'ncit:C16408', 'source': [], 'score': 0.7546381950378418, 'provenance': {'method': 'SKEMA-TR-Embedding', 'timestamp': '2024-03-20T23:58:20.733768'}}], 'data_columns': None}}, {'type': 'anchored_entity', 'amr_element_id': None, 'payload': {'id': {'id': 'R:-1621439126'}, 'mentions': [{'id': {'id': 'T:816130011'}, 'name': 't. beta', 'extraction_source': {'page': 3, 'block': 2, 'surrounding_passage': 'where N is the total population , S ( t ) , E ( t ) , I ( t ) , R ( t ) and D ( t ) , are the number of people susceptible , exposed , infected , recovered and dead on day t. beta is the expected number of people an infected person infects per day , gamma is the proportion of recovery per day , delta is the incubation period , alpha is the fatality rate due to the infection and rho is the inverse of the average number of days for an infected person to die if he does not recover .', 'char_start': 149, 'char_end': 156, 'document_reference': {'id': 'ijerp.pdf'}}, 'provenance': {'method': 'Skema TR Pipeline rules', 'timestamp': '2024-03-20T23:58:20.734729'}}], 'text_descriptions': [{'id': {'id': 'T:254088697'}, 'description': 'day t.', 'grounding': [], 'extraction_source': {'page': 3, 'block': 2, 'surrounding_passage': None, 'char_start': 145, 'char_end': 151, 'document_reference': {'id': 'ijerp.pdf'}}, 'provenance': {'method': 'Skema TR Pipeline rules', 'timestamp': '2024-03-20T23:58:20.734729'}}], 'value_descriptions': [], 'groundings': [], 'data_columns': None}}, {'type': 'anchored_entity', 'amr_element_id': None, 'payload': {'id': {'id': 'E:-1984431110'}, 'mentions': [{'id': {'id': 'T:920174442'}, 'name': 'alpha', 'extraction_source': {'page': 3, 'block': 2, 'surrounding_passage': 'where N is the total population , S ( t ) , E ( t ) , I ( t ) , R ( t ) and D ( t ) , are the number of people susceptible , exposed , infected , recovered and dead on day t. beta is the expected number of people an infected person infects per day , gamma is the proportion of recovery per day , delta is the incubation period , alpha is the fatality rate due to the infection and rho is the inverse of the average number of days for an infected person to die if he does not recover .', 'char_start': 303, 'char_end': 308, 'document_reference': {'id': 'ijerp.pdf'}}, 'provenance': {'method': 'Skema TR Pipeline rules', 'timestamp': '2024-03-20T23:58:20.734805'}}], 'text_descriptions': [{'id': {'id': 'T:-1889939553'}, 'description': 'fatality rate', 'grounding': [{'grounding_text': 'case fatality rate', 'grounding_id': 'cemo:case_fatality_rate ...

# %% [markdown]
# ### Ground Entities to MIRA concepts using embedding similarity

# %%
import requests

# Endpint configuration. Set the host correctly depending on where are you running this code snippet
# ENDPOINT="https://api.askem.lum.ai"
ENDPOINT = "http://127.0.0.1:8000" # Uncomment this line to use the docker compose service

queries = {"queries": ["infected", "suceptible"]}
params = {"k": 5}
response = requests.post(f"{ENDPOINT}/text-reading/ground_to_mira", params=params, json=queries)

if response.status_code == 200:
    print(response.json())
else:
	print(f"Error {response.status_code} - {response.text}")
# Out:
